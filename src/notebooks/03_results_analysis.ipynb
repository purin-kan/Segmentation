# %% [markdown]
# # 03 - Results Analysis
#
# Run after one or more `02_run_methods.ipynb` passes have written CSVs to `results/`.
# Loads per-method metric summaries, builds the comparison table, and renders
# qualitative overlays for a few representative B-scans (implementation_plan.md > Evaluation).

# %%
import glob
import pandas as pd

summaries = {
    path.split('/')[-1].removesuffix('.csv'): pd.read_csv(path)
    for path in glob.glob('results/*.csv')
}
summaries
