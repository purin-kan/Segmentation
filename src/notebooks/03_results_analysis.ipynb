# %% [markdown]
# # 03 - Results Analysis
#
# Run after one or more `02_run_methods.ipynb` passes have written CSVs under `OUTPUT_ROOT`
# (the Drive-backed `MyDrive/Segmentation/output`, defined in the setup notebook's Drive cell).
# Loads per-method metric summaries, builds the comparison table, and renders qualitative overlays
# for a few representative B-scans (implementation_plan.md > Evaluation).

# %%
import glob
import pandas as pd
from pathlib import Path

# Reads the CSVs 02_run_methods.ipynb wrote under OUTPUT_ROOT (Drive-backed).
summaries = {
    Path(path).stem: pd.read_csv(path)
    for path in glob.glob(str(OUTPUT_ROOT / '*.csv'))
}
summaries
